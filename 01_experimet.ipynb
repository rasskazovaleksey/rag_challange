# %% [markdown]
# # Export all data into data base

# %%
from lib.EmbeddingProvider import OpenAiEmbeddingProvider

from lib.DataRepository import DataRepository

repo = DataRepository(embedding=OpenAiEmbeddingProvider(), db_path="./data/db/open_ai_small")
repo.save_by_file()
# Out:
# /Users/alex/Projects/rag_challange/lib/EmbeddingProvider.py:26: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(
# /Users/alex/Projects/rag_challange/lib/DataRepository.py:19: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   self.db = Chroma(collection_name=name, persist_directory=db_path, embedding_function=self.embedding.provide())
# Progress: 0/39
# Loading documents from ./data/r2.0-test/pdfs/9cc771c2171bacc138cda4e7d68b8b427a514d81.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 1425
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 1/39
# Loading documents from ./data/r2.0-test/pdfs/f393170837ab7636d83fdc105279dfc61ebeb017.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 390
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 2/39
# Loading documents from ./data/r2.0-test/pdfs/a34c22665bada80d76b98b0e794096aefc06758a.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 1443
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 3/39
# Loading documents from ./data/r2.0-test/pdfs/7820b6e9487202b30f2883a6df91ae76f9461f2f.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 654
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 4/39
# Loading documents from ./data/r2.0-test/pdfs/58b196e02c2d9749d968a29039e9c2b29d3d31e1.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 508
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 5/39
# Loading documents from ./data/r2.0-test/pdfs/d3a834539b046a49708161a6c0d35aad29dd15ec.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 462
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 6/39
# Loading documents from ./data/r2.0-test/pdfs/c51f3c5aff7bea6fbc0bb7537838fa2f44f35c23.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 603
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 7/39
# Loading documents from ./data/r2.0-test/pdfs/601aba58deffc81230c837404aa883de0d1dde1c.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 173
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 8/39
# Loading documents from ./data/r2.0-test/pdfs/42f03832077a92b3b34855cb7f9ef93563143838.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 577
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 9/39
# Loading documents from ./data/r2.0-test/pdfs/79ffb9b8682aa565172233c070a47d944464644c.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 923
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 10/39
# Loading documents from ./data/r2.0-test/pdfs/612279ce81b538da24834af47131cc73e8c01a80.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 460
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 11/39
# Loading documents from ./data/r2.0-test/pdfs/cca42744d1a97475ccd14a5c2b98876b6d379982.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 1207
# Number of existing documents in DB: 8825
# No new documents to add
# Progress: 12/39
# Loading documents from ./data/r2.0-test/pdfs/f75ff9d631e7efdb86db68ab8ba395de221d9019.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 905
# Number of existing documents in DB: 8825
# Adding new documents: 905
# Progress: 13/39
# Loading documents from ./data/r2.0-test/pdfs/cd9239df47b2f0addd9cdd50d0fab4494414bba5.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 468
# Number of existing documents in DB: 9730
# Adding new documents: 468
# Progress: 14/39
# Loading documents from ./data/r2.0-test/pdfs/56262704bde6b584dcebfa644faa23a953498a79.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 702
# Number of existing documents in DB: 10198
# Adding new documents: 702
# Progress: 15/39
# Loading documents from ./data/r2.0-test/pdfs/61c082634d8902124bd48f55ab93ca0fb0599462.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 991
# Number of existing documents in DB: 10900
# Adding new documents: 991
# Progress: 16/39
# Loading documents from ./data/r2.0-test/pdfs/20c4badd4303f7aba1a298d84be3722fa84e0c67.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 795
# Number of existing documents in DB: 11891
# Adding new documents: 795
# Progress: 17/39
# Loading documents from ./data/r2.0-test/pdfs/49a9bf0542f3e5ff0250064bfed4369ecf6c8a09.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 334
# Number of existing documents in DB: 12686
# Adding new documents: 334
# Progress: 18/39
# Loading documents from ./data/r2.0-test/pdfs/ea4b61f74a604df117176e74b11f5780fb473a31.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 686
# Number of existing documents in DB: 13020
# Adding new documents: 686
# Progress: 19/39
# Loading documents from ./data/r2.0-test/pdfs/62367207e1e1747a92aaba83055fea26e9a2d684.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 251
# Number of existing documents in DB: 13706
# Adding new documents: 251
# Progress: 20/39
# Loading documents from ./data/r2.0-test/pdfs/7c55d7900a241e732c145687598d43c915a678f9.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 555
# Number of existing documents in DB: 13957
# Adding new documents: 555
# Progress: 21/39
# Loading documents from ./data/r2.0-test/pdfs/91aca730786f67b17ddcdb92319f859c5745ae74.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 439
# Number of existing documents in DB: 14512
# Adding new documents: 439
# Progress: 22/39
# Loading documents from ./data/r2.0-test/pdfs/6df434795a611c7fc88c75c728a96e400fc5b74d.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 741
# Number of existing documents in DB: 14951
# Adding new documents: 741
# Progress: 23/39
# Loading documents from ./data/r2.0-test/pdfs/dda7722dd2e90c9942ed383957b527873cc74174.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 287
# Number of existing documents in DB: 15692
# Adding new documents: 287
# Progress: 24/39
# Loading documents from ./data/r2.0-test/pdfs/0a9e39e1d2e176f3a766a0e86af82772f1654a6e.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 889
# Number of existing documents in DB: 15979
# Adding new documents: 889
# Progress: 25/39
# Loading documents from ./data/r2.0-test/pdfs/54e625a049a1713eb5a338b64858c06d74e52489.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 435
# Number of existing documents in DB: 16868
# Adding new documents: 435
# Progress: 26/39
# Loading documents from ./data/r2.0-test/pdfs/b03044c60d02a0a5557f95f6afb59e5ffc487799.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 429
# Number of existing documents in DB: 17303
# Adding new documents: 429
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 31 0 (offset 0)
# Ignoring wrong pointing object 33 0 (offset 0)
# Ignoring wrong pointing object 41 0 (offset 0)
# Ignoring wrong pointing object 43 0 (offset 0)
# Ignoring wrong pointing object 48 0 (offset 0)
# Ignoring wrong pointing object 50 0 (offset 0)
# Ignoring wrong pointing object 117 0 (offset 0)
# Ignoring wrong pointing object 128 0 (offset 0)
# Ignoring wrong pointing object 133 0 (offset 0)
# Ignoring wrong pointing object 138 0 (offset 0)
# Ignoring wrong pointing object 144 0 (offset 0)
# Ignoring wrong pointing object 149 0 (offset 0)
# Ignoring wrong pointing object 157 0 (offset 0)
# Ignoring wrong pointing object 168 0 (offset 0)
# Ignoring wrong pointing object 170 0 (offset 0)
# Ignoring wrong pointing object 197 0 (offset 0)
# Ignoring wrong pointing object 199 0 (offset 0)
# Ignoring wrong pointing object 211 0 (offset 0)
# Ignoring wrong pointing object 217 0 (offset 0)
# Ignoring wrong pointing object 222 0 (offset 0)
# Progress: 27/39
# Loading documents from ./data/r2.0-test/pdfs/8dd1306c26c63913495fe81dde5180033b39fc44.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 249
# Number of existing documents in DB: 17732
# Adding new documents: 249
# Progress: 28/39
# Loading documents from ./data/r2.0-test/pdfs/30b729c124a24ff21f37431dab6b58dfe7ba56fa.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 172
# Number of existing documents in DB: 17981
# Adding new documents: 172
# Progress: 29/39
# Loading documents from ./data/r2.0-test/pdfs/5ac3ccdec033f81fab4c2ed9ae86553f4904a450.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 788
# Number of existing documents in DB: 18153
# Adding new documents: 788
# Progress: 30/39
# Loading documents from ./data/r2.0-test/pdfs/873f84bbc485e5c04065c9b13b15e7129bd255fe.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 225
# Number of existing documents in DB: 18941
# Adding new documents: 225
# Progress: 31/39
# Loading documents from ./data/r2.0-test/pdfs/ed55750eae9cb7d893e6484b92496639172717cd.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 822
# Number of existing documents in DB: 19166
# Adding new documents: 822
# Progress: 32/39
# Loading documents from ./data/r2.0-test/pdfs/63688d5d0b4f12e9f847c5407439a1ec46047a4a.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 307
# Number of existing documents in DB: 19988
# Adding new documents: 307
# Progress: 33/39
# Loading documents from ./data/r2.0-test/pdfs/f973dd219c534accb0d4e72d8e12f51284d48d10.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 559
# Number of existing documents in DB: 20295
# Adding new documents: 559
# Progress: 34/39
# Loading documents from ./data/r2.0-test/pdfs/9938e66d5f0b65c66c8a404f02c1301d32991666.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 511
# Number of existing documents in DB: 20854
# Adding new documents: 511
# Progress: 35/39
# Loading documents from ./data/r2.0-test/pdfs/a6f23184a87f3343f17e8e8ed08f604615cdefc1.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 554
# Number of existing documents in DB: 21365
# Adding new documents: 554
# Progress: 36/39
# Loading documents from ./data/r2.0-test/pdfs/9b3fa9062a804f0f5a5dbfa46309ed3354cd680b.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 269
# Number of existing documents in DB: 21919
# Adding new documents: 269
# Progress: 37/39
# Loading documents from ./data/r2.0-test/pdfs/69b472e4c05986db72ff8e547bb220e2d222b7ef.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 1401
# Number of existing documents in DB: 22188
# Adding new documents: 1401
# Progress: 38/39
# Loading documents from ./data/r2.0-test/pdfs/da8afefdc3840175c9f26a4dbbed05e250a342cc.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 764
# Number of existing documents in DB: 23589
# Adding new documents: 764
# Progress: 39/39
# Loading documents from ./data/r2.0-test/pdfs/69a9dcb0bb6a46e2ff9f969d035e1774a2d49ef1.pdf...
# Splitting documents...
# Appending chunk ids...
# Filtering documents...
# Number of chunks: 683
# Number of existing documents in DB: 24353
# Adding new documents: 683

# %% [markdown]
# # Query the data base

# %%
question = "According to the annual report, what is the Operating margin (%) for Altech Chemicals Ltd  (within the last period or at the end of the last period)? If data is not available, return 'N/A'"

rag = repo.query(question, k=10)
print(rag)
# Out:
# [(Document(metadata={'author': 'Rachel Casotti', 'creationdate': '2022-10-19T12:06:13+08:00', 'creator': 'CorelDRAW 2022', 'id': '63688d5d0b4f12e9f847c5407439a1ec46047a4a:76:0', 'moddate': '2022-10-19T16:17:25+08:00', 'page': 76, 'page_label': '77', 'producer': 'Corel PDF Engine Version 24.2.0.444', 'source': './data/r2.0-test/pdfs/63688d5d0b4f12e9f847c5407439a1ec46047a4a.pdf', 'title': '2022 Annual Report 03.cdr', 'total_pages': 92}, page_content='ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 46 -    28.   Controlled entities          Investments in controlled entities comprise:          Name  Beneficial percentage  held by economic  entity Principal activities  2022 2021  % %  Altech Chemicals Ltd      Parent entity             Wholly owned and/or controlled entities:          Altech Chemicals Sdn Bhd (Malaysia) 100 100 HPA Plant  Altech Industries Germany GmbH 75 75 Battery Materials  Plant  Altech Meckering Pty Ltd 100 100 Kaolin Mine  Altech Chemicals Australia Pty Ltd 100 100  Intellectual  Property/Patent  Holder  Canning Coal Pty Ltd 100 100 Mineral exploration  Altech Chemicals Sdn Bhd is incorporated in Malaysia, and Altech Industries Germany GmbH is incorporated in Germany, all other controlled  entities are incorporated in Australia. Altech Chemicals Limited is the head entity of the consolidated group, which includes all of the controlled  entities.'), 0.7829548120498657), (Document(metadata={'author': 'Rachel Casotti', 'creationdate': '2022-10-19T12:06:13+08:00', 'creator': 'CorelDRAW 2022', 'id': '63688d5d0b4f12e9f847c5407439a1ec46047a4a:35:0', 'moddate': '2022-10-19T16:17:25+08:00', 'page': 35, 'page_label': '36', 'producer': 'Corel PDF Engine Version 24.2.0.444', 'source': './data/r2.0-test/pdfs/63688d5d0b4f12e9f847c5407439a1ec46047a4a.pdf', 'title': '2022 Annual Report 03.cdr', 'total_pages': 92}, page_content='ALTECH CHEMICALS LIMITED  DIRECTORS’ REPORT  For the year ended 30 June 2022    - 5 -    SIGNIFICANT CHANGES IN THE STATE OF AFFAIRS    In the opinion of the directors, there were no other significant changes in the state of affairs of the Group that occurred during the financial  year under review.    EVENTS SUBSEQUENT TO BALANCE DATE  On 14 September 2022, Altech announced that it had entered into a Joint Venture with Fraunhofer IKTS in relation to commercialisation  of a 100 MWh Sodium Alumina Solid State Battery Plant for grid storage.    Further, there has not arisen since the end of the financial year any other item, transaction or event of a material and unusual nature likely,  in the opinion of the directors  of the Company to affect substantially the operations of the Group, the results of those operations or the  state of affairs of the Group in subsequent financial years.    OPTIONS OVER UNISSUED CAPITAL'), 0.7946504354476929), (Document(metadata={'author': 'Rachel Casotti', 'creationdate': '2022-10-19T12:06:13+08:00', 'creator': 'CorelDRAW 2022', 'id': '63688d5d0b4f12e9f847c5407439a1ec46047a4a:51:0', 'moddate': '2022-10-19T16:17:25+08:00', 'page': 51, 'page_label': '52', 'producer': 'Corel PDF Engine Version 24.2.0.444', 'source': './data/r2.0-test/pdfs/63688d5d0b4f12e9f847c5407439a1ec46047a4a.pdf', 'title': '2022 Annual Report 03.cdr', 'total_pages': 92}, page_content='ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 21 -    GENERAL INFORMATION  The financial statements cover Altech Chemicals Limited as a consolidated entity consisting of Altech Chemicals Limited and t he entities it controlled  at the end of, or during, the year. The financial statements are presented in Australian dollars, which is Altech Chemicals Limited’s functional and  presentation currency.    Altech Chemicals Limited is a listed public company limited by shares, incorporated and domiciled in Australia. Its registered office and principal place  of business is:    Suite 8, 295 Rokeby Road  Subiaco  Western Australia ...

# %% [markdown]
# # Query LLM

# %%
from lib.Agent import OpenAIAgent

agent = OpenAIAgent()
agent.query(question, rag)
# Out:
# Human: Answer the question based only on the following context:
#
# ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 46 -    28.   Controlled entities          Investments in controlled entities comprise:          Name  Beneficial percentage  held by economic  entity Principal activities  2022 2021  % %  Altech Chemicals Ltd      Parent entity             Wholly owned and/or controlled entities:          Altech Chemicals Sdn Bhd (Malaysia) 100 100 HPA Plant  Altech Industries Germany GmbH 75 75 Battery Materials  Plant  Altech Meckering Pty Ltd 100 100 Kaolin Mine  Altech Chemicals Australia Pty Ltd 100 100  Intellectual  Property/Patent  Holder  Canning Coal Pty Ltd 100 100 Mineral exploration  Altech Chemicals Sdn Bhd is incorporated in Malaysia, and Altech Industries Germany GmbH is incorporated in Germany, all other controlled  entities are incorporated in Australia. Altech Chemicals Limited is the head entity of the consolidated group, which includes all of the controlled  entities.
#
# ---
#
# ALTECH CHEMICALS LIMITED  DIRECTORS’ REPORT  For the year ended 30 June 2022    - 5 -    SIGNIFICANT CHANGES IN THE STATE OF AFFAIRS    In the opinion of the directors, there were no other significant changes in the state of affairs of the Group that occurred during the financial  year under review.    EVENTS SUBSEQUENT TO BALANCE DATE  On 14 September 2022, Altech announced that it had entered into a Joint Venture with Fraunhofer IKTS in relation to commercialisation  of a 100 MWh Sodium Alumina Solid State Battery Plant for grid storage.    Further, there has not arisen since the end of the financial year any other item, transaction or event of a material and unusual nature likely,  in the opinion of the directors  of the Company to affect substantially the operations of the Group, the results of those operations or the  state of affairs of the Group in subsequent financial years.    OPTIONS OVER UNISSUED CAPITAL
#
# ---
#
# ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 21 -    GENERAL INFORMATION  The financial statements cover Altech Chemicals Limited as a consolidated entity consisting of Altech Chemicals Limited and t he entities it controlled  at the end of, or during, the year. The financial statements are presented in Australian dollars, which is Altech Chemicals Limited’s functional and  presentation currency.    Altech Chemicals Limited is a listed public company limited by shares, incorporated and domiciled in Australia. Its registered office and principal place  of business is:    Suite 8, 295 Rokeby Road  Subiaco  Western Australia 6008    The financial statements were authorised for issue, in accordance with the resolution of directors. The directors have the power to amend and reissue  the financial statements.    1. SUMMARY OF SIGNIFICANT ACCOUNTING POLICIES
#
# ---
#
# ALTECH CHEMICALS LIMITED  CONSOLIDATED STATEMENT OF PROFIT AND LOSS AND OTHER COMPREHENSIVE INCOME   For the year ended 30 June 2022  - 17 - 30-Jun-22 30-Jun-21  Notes $ $  Revenue from ordinary activities  Interest Income 3(a) 227,104  117,619  R&D tax refunds 3(a) 241,555 -  Other income 3(a) - 7,941,804 Total Income 468,659  8,059,423  Expenses  Employee benefit expense (incorporating director fees)  (2,201,945)  (1,345,086)  Depreciation (328,891)  (230,623)  Other expenses 3(b) (2,414,378)  (3,094,837)  Share-based payments 16(e) (583,627)  (242,436)  Share in profit / (loss) of associate - Altech Advanced Materials AG  (328,979)  (200,006)  Impairment - investment in associate (AAM AG) (119,051)  (620,569)  Research and development (546,262) -  Interest expense (3,400) -  Forex gain / (loss) (9,919) -  Profit / (loss) before income tax expense (6,067,791)  2,325,866  Income tax benefit 265,362  -  Net profit / (loss) from continuing operations (5,802,429)  2,325,866
#
# ---
#
# ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 33 -    3.   Loss for the year includes the following specific income and  expenses 30-Jun-22 30-Jun-21    $ $  (a) Revenue      Interest income   227,104   117,619   Sale of 25% equity of Altech Industries Germany GmbH   -   7,941,108   R&D tax refund  241,555 -  Other Income   -  696        468,659  8,059,423   (b) Other expenses        Accounting and audit fees    (55,180)  (50,268)  ASX and share registry fees   (121,903)  (74,759)  Corporate & consulting   (836,490)  (1,095,422)  Insurance expense    (276,927)  (255,015)  Occupancy   (166,277)  (123,054)  Legal fees   (174,618)  (127,256)  Investor relations and marketing   (477,796)  (218,669)  Office & administration   (305,188)  (258,943)  Foreign exchange translation   -  (891,451)      (2,414,378)  (3,094,837)
#
# ---
#
# ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 38 -    11.  Development expenditure 30-Jun-22 30-Jun-21      $ $  Carrying amount at the beginning of the year    36,463,669  36,628,368   Development expenditure incurred during the year (at cost) including foreign exchange movements 1,215,821 (164,699)   Carrying amount at the end of the year    37,679,490   36,463,669       The Malaysian HPA plant is part way constructed, and is currently on care and maintenance.  The Company requires further capital in order to  complete the plant.  Should the Company not be successful in raising sufficient additional capital, the plant will not be constructed in full.  Should  this occur, the carrying value shown will not be realised.     12.  Investment in Associate (Altech Advanced Materials AG) 30-Jun-22 30-Jun-21     $ $  Carrying amount at the beginning of the period   2,085,439   2,891,365
#
# ---
#
# ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 35 -    5.   Earnings per share   30-Jun-22 30-Jun-21      $ $  Basic profit (loss) per share   (0.004)  0.002   Diluted profit (loss) per share   (0.004)   0.002            The weighted average number of ordinary shares used in the calculation of basic earnings per  share was:     Number Number   1,080,764,077 1,018,048,889                    6.   Cash and cash equivalents       (a) Cash at the end of the financial year as shown in the statement of cash flows is reconciled to the related items in the Consolidated Statement  of Financial Position as follows:      30-Jun-22 30-Jun-21      $ $   Cash at bank and on hand   10,912,939  6,728,978            (b) Reconciliation of the loss from ordinary activities after income tax to the net cash flows used in operating activities:        30-Jun-22 30-Jun-21    $ $
#
# ---
#
# ALTECH CHEMICALS LIMITED  DIRECTORS’ REPORT  For the year ended 30 June 2022    - 10 -    REMUNERATION REPORT (continued)  No performance rights held by directors or key management personnel that were outstanding as at 30 June 2022 or awarded since that  date, have vested.    Details of remuneration  The following tables show details of the remuneration received by Altech Chemicals Limited key management personnel for the current  and previous financial year.      Primary Compensation Post- Employment  Equity  Compensation        2021/22  Base  Salary/Fees  Short Term  Incentive  Superannuation  Contributions  Performance  Rights Total  $ $ $ $ $  Directors            I Tan – managing director 435,000  95,700     53,070  363,640  947,410   L Atkins – non-executive chairman 95,000  -     9,500  12,485 116,985   D Tenardi – non-executive 70,000  -     7,000  12,485 89,485   P Bailey – non-executive(i) 70,000  -     -    12,485 82,485
#
# ---
#
# ALTECH CHEMICALS LIMITED  NOTES TO THE FINANCIAL STATEMENTS  For the year ended 30 June 2022    - 44 -    22.   Expenditure commitments (continued)        (b) Intercompany Loan Commitments        0n 1 May 2015, the Company entered into an Intercompany Loan Agreement (Agreement) with its 100% owned subsidiary Altech Chemicals S dn Bhd  (ATCSB).  Under the terms of the Agreement:  • The Company extends a loan facility up to the amount of $100,000,000 to provide funding to enable ATCSB to advance the development of a high  purity alumina manufacturing facility in Malaysia.  • Interest payable is nil for the period up to and preceding the date at which ATCSB commences commercial production from its proposed high purity  alumina manufacturing facility.  • From the date at which ATCSB commences commercial production from its proposed high purity alumina manufac turing facility, interest shall be  charged on the loan at an arms-length commercial rate of interest.
#
# ---
#
# ALTECH CHEMICALS LIMITED  CONSOLIDATED STATEMENT OF CASHFLOWS  For the year ended 30 June 2022  - 20 - 30-Jun-22 30-Jun-21  Notes $ $  Cash Flows from Operating Activities  Payments to suppliers, contractors and employees (5,286,968)  (3,801,433)  R&D refund received 241,555 -  Interest received  227,104  117,619  Interest paid (3,400)  -  Deposits Paid - (15,929) Net cash flows used in operating activities 6(b)  (4,821,709)  (3,699,743)  Cash Flows from Investing Activities  Acquisition of plant and equipment  (2,443,218)  (95,515)  Payment for investment in Altech Advance Materials AG (1,713,805) (1,981,363)  Payments for development expenditure - (5,077,643) Payments for exploration expenditure  (177,838)  (38,129)  Proceeds from sale of 25% of Altech Industries Germany Gmbh - 403,819 Net cash flows used in investing activities  (4,334,862)  (6,788,831)  Cash Flows from Financing Activities  Payments for KfW IPEX-Bank loan facility - (273,773)
#
# ---
#
# Answer the question based on the above context: According to the annual report, what is the Operating margin (%) for Altech Chemicals Ltd  (within the last period or at the end of the last period)? If data is not available, return 'N/A'
# 'N/A'
